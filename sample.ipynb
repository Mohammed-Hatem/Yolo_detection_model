# %%
# !pip install ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(data="/home/mohammed/PycharmProjects/JupyterProject/Dataset/data.yaml", epochs=200)
# Out:
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5804MiB)
# ...
